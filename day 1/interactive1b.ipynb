# %% [markdown]
# # Day 1: Session 1B - Python Essentials
#
# [Session Webpage](https://eds-217-essential-python.github.io/course-materials/interactive-sessions/1b_python_essentials.html)
#
# Date: 08/31/2026

# %%
temperature = 21

# %%
site_name = "Santa Barbara"

# %%
temperature
# Out:
# 21

# %%
high_temp = 24
low_temp = 12
temp_range = high_temp - low_temp
temp_range
# Out:
# 12

# %%
description = """ 
This dataset records daily air temperature at three stations
"""
description
# Out:
# ' \nThis dataset records daily air temperature at three stations\n'

# %%
type(temperature)
# Out:
# int

# %%
count = 42          # an int
rainfall = 3.5      # a float

# %%
type(rainfall)
# Out:
# float

# %%
type(description)
# Out:
# str

# %%
description.upper()
# Out:
# ' \nTHIS DATASET RECORDS DAILY AIR TEMPERATURE AT THREE STATIONS\n'

# %%
print(type(description))
print(type(rainfall))
print(type(count))
# Out:
# <class 'str'>
# <class 'float'>
# <class 'int'>

# %%
name = "Alice"
print(f"Hello, {name}!")
print(f"The low temperature was {low_temp} and the high temperature was {high_temp} so the temperature range is {temp_range}")
print(f"low:{low_temp} \nhigh:{high_temp} \nrange:{temp_range}")
# Out:
# Hello, Alice!
# The low temperature was 12 and the high temperature was 24 so the temperature range is 12
# low:12
# high:24
# range:12
