# %% [markdown]
# # Day 2: Session 2A - Reading Data into pandas
#
# [Session Webpage](https://eds-217-essential-python.github.io/course-materials/interactive-sessions/2a_reading_data.html)
#
# Date: 09/01/2026

# %%
import pandas as pd

# %%
url = 'https://eds-217-essential-python.github.io/data/openaq_goleta_measurments.csv'

# %%
goleta = pd.read_csv(url)

# %%
goleta.head()
# Out:
#    location_id location_name parameter  value unit                datetimeUtc  \
# 0         1186        Goleta        o3  0.025  ppm  2024-07-12T01:00:00+00:00
# 1         1186        Goleta        o3  0.028  ppm  2024-07-12T02:00:00+00:00
# 2         1186        Goleta        o3  0.029  ppm  2024-07-12T03:00:00+00:00
# 3         1186        Goleta        o3  0.027  ppm  2024-07-12T04:00:00+00:00
# 4         1186        Goleta        o3  0.026  ppm  2024-07-12T05:00:00+00:00
#
#                datetimeLocal             timezone   latitude   longitude  country_iso  \
# 0  2024-07-11T18:00:00-07:00  America/Los_Angeles  34.445301 -119.827797          NaN
# 1  2024-07-11T19:00:00-07:00  America/Los_Angeles  34.445301 -119.827797          NaN
# 2  2024-07-11T20:00:00-07:00  America/Los_Angeles  34.445301 -119.827797          NaN
# 3  2024-07-11T21:00:00-07:00  America/Los_Angeles  34.445301 -119.827797          NaN
# ...

# %%
santa_barbara = pd.read_csv('https://eds-217-essential-python.github.io/data/openaq_santa_barbara_measurments.csv')

# %% [markdown]
# DataFrames and Series

# %%
goleta['value']
# Out:
# 0        0.025
# 1        0.028
# 2        0.029
# 3        0.027
# 4        0.026
#          ...
# 1957    10.000
# 1958     8.000
# 1959     8.000
# 1960     9.000
# 1961     5.000
# Name: value, Length: 1962, dtype: float64

# %%
print(type(goleta))
print(type(goleta['value']))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
goleta['value'].head()
# Out:
# 0    0.025
# 1    0.028
# 2    0.029
# 3    0.027
# 4    0.026
# Name: value, dtype: float64

# %%
goleta['parameter']
# Out:
# 0         o3
# 1         o3
# 2         o3
# 3         o3
# 4         o3
#         ...
# 1957    pm25
# 1958    pm25
# 1959    pm25
# 1960    pm25
# 1961    pm25
# Name: parameter, Length: 1962, dtype: object

# %%
goleta['parameter'].head()
# Out:
# 0    o3
# 1    o3
# 2    o3
# 3    o3
# 4    o3
# Name: parameter, dtype: object

# %%
type(goleta['parameter'])
# Out:
# pandas.core.series.Series

# %% [markdown]
# Column names as a list

# %%
goleta.columns
# Out:
# Index(['location_id', 'location_name', 'parameter', 'value', 'unit', 'datetimeUtc',
#        'datetimeLocal', 'timezone', 'latitude', 'longitude', 'country_iso', 'isMobile',
#        'isMonitor', 'owner_name', 'provider'],
#       dtype='object')

# %%
column_names = goleta.columns.tolist()
column_names
# Out:
# ['location_id',
#  'location_name',
#  'parameter',
#  'value',
#  'unit',
#  'datetimeUtc',
#  'datetimeLocal',
#  'timezone',
#  'latitude',
#  'longitude',
#  'country_iso',
#  'isMobile',
#  'isMonitor',
#  'owner_name',
#  'provider']

# %%
parameters_we_care_about = ['o3', 'pm25']
parameters_we_care_about
# Out:
# ['o3', 'pm25']

# %%
print(column_names[0])
print(column_names[1])
# Out:
# location_id
# location_name

# %%
len(column_names)
# Out:
# 15

# %%
column_names[-1]
# Out:
# 'provider'

# %% [markdown]
# Selecting columns with a list

# %%
keep = ['location_name', 'parameter', 'value', 'unit']
goleta[keep].head()
# Out:
#   location_name parameter  value unit
# 0        Goleta        o3  0.025  ppm
# 1        Goleta        o3  0.028  ppm
# 2        Goleta        o3  0.029  ppm
# 3        Goleta        o3  0.027  ppm
# 4        Goleta        o3  0.026  ppm

# %%
goleta[['location_name', 'parameter', 'value', 'unit']].head()
# Out:
#   location_name parameter  value unit
# 0        Goleta        o3  0.025  ppm
# 1        Goleta        o3  0.028  ppm
# 2        Goleta        o3  0.029  ppm
# 3        Goleta        o3  0.027  ppm
# 4        Goleta        o3  0.026  ppm

# %%
time_columns = ['datetimeUtc' 'datetimeLocal']

# %%
goleta_by_time = pd.read_csv(url, index_col='datetimeLocal')
goleta_by_time.head()
# Out:
#                            location_id location_name parameter  value unit  \
# datetimeLocal
# 2024-07-11T18:00:00-07:00         1186        Goleta        o3  0.025  ppm
# 2024-07-11T19:00:00-07:00         1186        Goleta        o3  0.028  ppm
# 2024-07-11T20:00:00-07:00         1186        Goleta        o3  0.029  ppm
# 2024-07-11T21:00:00-07:00         1186        Goleta        o3  0.027  ppm
# 2024-07-11T22:00:00-07:00         1186        Goleta        o3  0.026  ppm
#
#                                          datetimeUtc             timezone   latitude  \
# datetimeLocal
# 2024-07-11T18:00:00-07:00  2024-07-12T01:00:00+00:00  America/Los_Angeles  34.445301
# 2024-07-11T19:00:00-07:00  2024-07-12T02:00:00+00:00  America/Los_Angeles  34.445301
# 2024-07-11T20:00:00-07:00  2024-07-12T03:00:00+00:00  America/Los_Angeles  34.445301
# 2024-07-11T21:00:00-07:00  2024-07-12T04:00:00+00:00  America/Los_Angeles  34.445301
# ...

# %%
goleta_by_time.columns.tolist()
# Out:
# ['location_id',
#  'location_name',
#  'parameter',
#  'value',
#  'unit',
#  'datetimeUtc',
#  'timezone',
#  'latitude',
#  'longitude',
#  'country_iso',
#  'isMobile',
#  'isMonitor',
#  'owner_name',
#  'provider']

# %%
goleta_by_time = pd.read_csv(url, index_col='datetimeUtc')
goleta_by_time.head()
# Out:
#                            location_id location_name parameter  value unit  \
# datetimeUtc
# 2024-07-12T01:00:00+00:00         1186        Goleta        o3  0.025  ppm
# 2024-07-12T02:00:00+00:00         1186        Goleta        o3  0.028  ppm
# 2024-07-12T03:00:00+00:00         1186        Goleta        o3  0.029  ppm
# 2024-07-12T04:00:00+00:00         1186        Goleta        o3  0.027  ppm
# 2024-07-12T05:00:00+00:00         1186        Goleta        o3  0.026  ppm
#
#                                        datetimeLocal             timezone   latitude  \
# datetimeUtc
# 2024-07-12T01:00:00+00:00  2024-07-11T18:00:00-07:00  America/Los_Angeles  34.445301
# 2024-07-12T02:00:00+00:00  2024-07-11T19:00:00-07:00  America/Los_Angeles  34.445301
# 2024-07-12T03:00:00+00:00  2024-07-11T20:00:00-07:00  America/Los_Angeles  34.445301
# 2024-07-12T04:00:00+00:00  2024-07-11T21:00:00-07:00  America/Los_Angeles  34.445301
# ...

# %% [markdown]
# # Day 2: Session 2B - Exploring a DataFrame
#
# [Session Webpage](https://eds-217-essential-python.github.io/course-materials/interactive-sessions/2b_exploring_data.html)
#
# Date: 09/01/2026

# %%
import pandas as pd

url = 'https://eds-217-essential-python.github.io/data/openaq_goleta_measurments.csv'
goleta = pd.read_csv(url)

# %%
goleta.head()
# Out:
#    location_id location_name parameter  value unit                datetimeUtc  \
# 0         1186        Goleta        o3  0.025  ppm  2024-07-12T01:00:00+00:00
# 1         1186        Goleta        o3  0.028  ppm  2024-07-12T02:00:00+00:00
# 2         1186        Goleta        o3  0.029  ppm  2024-07-12T03:00:00+00:00
# 3         1186        Goleta        o3  0.027  ppm  2024-07-12T04:00:00+00:00
# 4         1186        Goleta        o3  0.026  ppm  2024-07-12T05:00:00+00:00
#
#                datetimeLocal             timezone   latitude   longitude  country_iso  \
# 0  2024-07-11T18:00:00-07:00  America/Los_Angeles  34.445301 -119.827797          NaN
# 1  2024-07-11T19:00:00-07:00  America/Los_Angeles  34.445301 -119.827797          NaN
# 2  2024-07-11T20:00:00-07:00  America/Los_Angeles  34.445301 -119.827797          NaN
# 3  2024-07-11T21:00:00-07:00  America/Los_Angeles  34.445301 -119.827797          NaN
# ...

# %%
goleta.tail()
# Out:
#       location_id location_name parameter  value   unit                datetimeUtc  \
# 1957         1186        Goleta      pm25   10.0  µg/m³  2024-08-11T20:00:00+00:00
# 1958         1186        Goleta      pm25    8.0  µg/m³  2024-08-11T21:00:00+00:00
# 1959         1186        Goleta      pm25    8.0  µg/m³  2024-08-11T22:00:00+00:00
# 1960         1186        Goleta      pm25    9.0  µg/m³  2024-08-11T23:00:00+00:00
# 1961         1186        Goleta      pm25    5.0  µg/m³  2024-08-12T00:00:00+00:00
#
#                   datetimeLocal             timezone   latitude   longitude  country_iso  \
# 1957  2024-08-11T13:00:00-07:00  America/Los_Angeles  34.445301 -119.827797          NaN
# 1958  2024-08-11T14:00:00-07:00  America/Los_Angeles  34.445301 -119.827797          NaN
# 1959  2024-08-11T15:00:00-07:00  America/Los_Angeles  34.445301 -119.827797          NaN
# 1960  2024-08-11T16:00:00-07:00  America/Los_Angeles  34.445301 -119.827797          NaN
# ...

# %%
goleta.head(3)
# Out:
#    location_id location_name parameter  value unit                datetimeUtc  \
# 0         1186        Goleta        o3  0.025  ppm  2024-07-12T01:00:00+00:00
# 1         1186        Goleta        o3  0.028  ppm  2024-07-12T02:00:00+00:00
# 2         1186        Goleta        o3  0.029  ppm  2024-07-12T03:00:00+00:00
#
#                datetimeLocal             timezone   latitude   longitude  country_iso  \
# 0  2024-07-11T18:00:00-07:00  America/Los_Angeles  34.445301 -119.827797          NaN
# 1  2024-07-11T19:00:00-07:00  America/Los_Angeles  34.445301 -119.827797          NaN
# 2  2024-07-11T20:00:00-07:00  America/Los_Angeles  34.445301 -119.827797          NaN
#
#    isMobile  isMonitor                         owner_name provider
# 0       NaN        NaN  Unknown Governmental Organization   AirNow
# 1       NaN        NaN  Unknown Governmental Organization   AirNow
# 2       NaN        NaN  Unknown Governmental Organization   AirNow

# %%
goleta.shape
# Out:
# (1962, 15)

# %%
print("rows:", goleta.shape[0])
print("columns:", goleta.shape[1])
# Out:
# rows: 1962
# columns: 15

# %%
goleta.columns.tolist()
# Out:
# ['location_id',
#  'location_name',
#  'parameter',
#  'value',
#  'unit',
#  'datetimeUtc',
#  'datetimeLocal',
#  'timezone',
#  'latitude',
#  'longitude',
#  'country_iso',
#  'isMobile',
#  'isMonitor',
#  'owner_name',
#  'provider']

# %%
goleta.dtypes
# Out:
# location_id        int64
# location_name     object
# parameter         object
# value            float64
# unit              object
# datetimeUtc       object
# datetimeLocal     object
# timezone          object
# latitude         float64
# longitude        float64
# country_iso      float64
# isMobile         float64
# isMonitor        float64
# owner_name        object
# provider          object
# dtype: object

# %%
goleta.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1962 entries, 0 to 1961
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   location_id    1962 non-null   int64
#  1   location_name  1962 non-null   object
#  2   parameter      1962 non-null   object
#  3   value          1962 non-null   float64
#  4   unit           1962 non-null   object
#  5   datetimeUtc    1962 non-null   object
#  6   datetimeLocal  1962 non-null   object
#  7   timezone       1962 non-null   object
#  8   latitude       1962 non-null   float64
#  9   longitude      1962 non-null   float64
#  10  country_iso    0 non-null      float64
#  11  isMobile       0 non-null      float64
#  12  isMonitor      0 non-null      float64
#  13  owner_name     1962 non-null   object
#  14  provider       1962 non-null   object
# dtypes: float64(6), int64(1), object(8)
# memory usage: 230.1+ KB

# %%
goleta.isnull().sum()
# Out:
# location_id         0
# location_name       0
# parameter           0
# value               0
# unit                0
# datetimeUtc         0
# datetimeLocal       0
# timezone            0
# latitude            0
# longitude           0
# country_iso      1962
# isMobile         1962
# isMonitor        1962
# owner_name          0
# provider            0
# dtype: int64

# %%
goleta.describe()
# Out:
#        location_id        value      latitude     longitude  country_iso  isMobile  isMonitor
# count       1962.0  1962.000000  1.962000e+03  1.962000e+03          0.0       0.0        0.0
# mean        1186.0     6.378173  3.444530e+01 -1.198278e+02          NaN       NaN        NaN
# std            0.0     7.313763  2.132172e-14  2.842896e-14          NaN       NaN        NaN
# min         1186.0    -4.000000  3.444530e+01 -1.198278e+02          NaN       NaN        NaN
# 25%         1186.0     0.027000  3.444530e+01 -1.198278e+02          NaN       NaN        NaN
# 50%         1186.0     5.000000  3.444530e+01 -1.198278e+02          NaN       NaN        NaN
# 75%         1186.0    10.000000  3.444530e+01 -1.198278e+02          NaN       NaN        NaN
# max         1186.0    40.000000  3.444530e+01 -1.198278e+02          NaN       NaN        NaN

# %%
goleta['unit'].value_counts()
# Out:
# unit
# µg/m³    1251
# ppm       711
# Name: count, dtype: int64

# %% [markdown]
# for the above cell, Some rows are in micrograms per cubic metre and some are in parts per million. The mean of 6.4 was computed by averaging those two units together, so it does not describe any real quantity that anyone measured in Goleta.

# %%
print(goleta['longitude'].value_counts())
# Out:
# longitude
# -119.827797    1962
# Name: count, dtype: int64

# %%
goleta['parameter'].value_counts()
# Out:
# parameter
# pm25    734
# o3      711
# pm10    517
# Name: count, dtype: int64

# %%
goleta['location_name'].value_counts()
# Out:
# location_name
# Goleta    1962
# Name: count, dtype: int64

# %%
list_of_counts = goleta['datetimeLocal'].value_counts().to_list()

# %%
new_names = {
    'datetimeUtc': 'datetime_utc',
    'datetimeLocal': 'datetime_local',
}
new_names
# Out:
# {'datetimeUtc': 'datetime_utc', 'datetimeLocal': 'datetime_local'}

# %%
new_names['datetimeUtc']
# Out:
# 'datetime_utc'

# %%
goleta_renamed = goleta.rename(columns=new_names)
goleta_renamed.columns.tolist()
# Out:
# ['location_id',
#  'location_name',
#  'parameter',
#  'value',
#  'unit',
#  'datetime_utc',
#  'datetime_local',
#  'timezone',
#  'latitude',
#  'longitude',
#  'country_iso',
#  'isMobile',
#  'isMonitor',
#  'owner_name',
#  'provider']
